# %%
import time
import random
from selenium import webdriver
import csv
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import bs4
import pandas as pd

# %%
driver = webdriver.Chrome(executable_path=r'/Users/aniketmuluk/Downloads/chromedriver')

# %%
driver.get('http://www.mlb.com')

# %%
stats_header_bar = driver.find_element_by_class_name('megamenu-navbar-overflow__menu-item-link')

# %%
stats_header_bar.click()

# %%
hitting_season_element = driver.find_element_by_id('sp_hitting_season')
season_select = Select(hitting_season_element)

# %%
season_select.select_by_value('2015')

# %%
hitting_gametype_element = driver.find_element_by_id("sp_hitting_game_type")
gametype_select = Select(hitting_gametype_element)
gametype_select.select_by_value("'R'")

# %%
hitting_team = driver.find_element_by_xpath('//*[@id="st_parent"]')
hitting_team.click()

# %%
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = BeautifulSoup(data_html, 'html5lib')

# %%
column_head = []
col_by_row = []
def get_data_table():
    for tr in soup.tbody.findAll('tr'):
        row = [td.text.replace(u'\xa0',u'') for td in tr.findAll('td')]
        col_by_row.append(row)
        for th in soup.thead.tr.findAll('th'):
            if len(column_head)<len(col_by_row[0]):
                column_head.append(th.text.replace('▲','').replace('▼',''))
    print(column_head)
    print(col_by_row)

# %%
get_data_table()
# Out:
# ['RK', 'Team', '', 'League', 'G', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'SB', 'CS', 'AVG', 'OBP', 'SLG', 'OPS', 'IBB', 'HBP', 'SAC', 'SF', 'TB', 'XBH', 'GDP', 'GO', 'AO', 'GO_AO', 'NP', 'PA']
# ...

# %%
import pandas as pd


test = pd.DataFrame(col_by_row, columns=column_head)
test.set_index("RK")
test.to_csv('Question_1.csv')

# %%
test
# Out:
#     RK                   Team      League    G    AB    R     H   2B  3B  \
# 0    1         Detroit Tigers  det     AL  161  5605  689  1515  289  49
# 1    2      Toronto Blue Jays  tor     AL  162  5509  891  1480  308  17
# 2    3     Kansas City Royals   kc     AL  162  5575  724  1497  300  42
# 3    4   San Francisco Giants   sf     NL  162  5565  696  1486  288  39
# 4    5       Colorado Rockies  col     NL  162  5572  737  1479  274  49
# 5    6         Boston Red Sox  bos     AL  162  5640  748  1495  294  33
# 6    7   Arizona Diamondbacks  ari     NL  162  5649  720  1494  289  48
# 7    8          Miami Marlins  mia     NL  162  5463  613  1420  236  40
# 8    9     Pittsburgh Pirates  pit     NL  162  5631  697  1462  292  27
# 9   10          Texas Rangers  tex     AL  162  5511  751  1419  279  32
# 10  11      Cleveland Indians  cle     AL  161  5439  669  1395  303  29
# 11  12    St. Louis Cardinals  stl     NL  162  5484  647  1386  288  39
# ...

# %%
 print("Team with maximum home runs in regular season of 2015 {}".format(test.max()))
# Out:
# Team with maximum home runs in regular season of 2015 RK                           9
# Team      Washington Nationals
#                            was
# League                      NL
# G                          162
# AB                        5649
# R                          891
# H                         1515
# 2B                         308
# 3B                          49
# HR                         232
# RBI                        852
# BB                         570
# SO                         973
# SB                          98
# CS                          51
# AVG                       .270
# OBP                       .340
# SLG                       .457
# OPS                       .797
# IBB                         47
# HBP                         89
# SAC                         71
# SF                          62
# TB                        2518
# XBH                        557
# GDP                         99
# GO                        1921
# ...

# %% [markdown]
# Question 2:

# %%
hitting_AL = driver.find_element_by_xpath('//*[@id="st_hitting-0"]/fieldset[2]/label[2]')
hitting_AL.click()

# %%
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = BeautifulSoup(data_html, 'html5lib')

# %%
column_head1=[]
col_by_row1=[]
for tr in soup.tbody.findAll('tr'):
        row = [td.text.replace(u'\xa0',u'') for td in tr.findAll('td')]
        col_by_row1.append(row)
        for th in soup.thead.tr.findAll('th'):
            if len(column_head1)<len(col_by_row1[0]):
                column_head1.append(th.text.replace('▲','').replace('▼',''))

# %%
import pandas as pd


test1_AL = pd.DataFrame(col_by_row1, columns=column_head1)
test1_AL.set_index("RK")
test1_AL.to_csv('Question_2A.csv')

# %%
test1_AL
# Out:
#     RK                Team      League    G    AB    R     H   2B  3B  ...   \
# 0    1      Detroit Tigers  det     AL  161  5605  689  1515  289  49  ...
# 1    2   Toronto Blue Jays  tor     AL  162  5509  891  1480  308  17  ...
# 2    3  Kansas City Royals   kc     AL  162  5575  724  1497  300  42  ...
# 3    4      Boston Red Sox  bos     AL  162  5640  748  1495  294  33  ...
# 4    5       Texas Rangers  tex     AL  162  5511  751  1419  279  32  ...
# 5    6   Cleveland Indians  cle     AL  161  5439  669  1395  303  29  ...
# 6    7      Tampa Bay Rays   tb     AL  162  5485  644  1383  278  32  ...
# 7    8    New York Yankees  nyy     AL  162  5567  764  1397  272  19  ...
# 8    9   Oakland Athletics  oak     AL  162  5600  694  1405  277  46  ...
# 9   10   Baltimore Orioles  bal     AL  162  5485  713  1370  246  20  ...
# 10  11      Houston Astros  hou     AL  162  5459  729  1363  278  26  ...
# ...

# %%
a=test1_AL['HR']
import numpy as np

m=[]
for i in a:
    m.append(int(i))
m
Average_AL = np.mean(m)
Average_AL
# Out:
# 175.6

# %% [markdown]
# Accessing NL

# %%
hitting_NL = driver.find_element_by_xpath('//*[@id="st_hitting-0"]/fieldset[2]/label[3]')
hitting_NL.click()

# %%
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = BeautifulSoup(data_html, 'html5lib')

# %%
column_head2=[]
col_by_row2=[]
for tr in soup.tbody.findAll('tr'):
        row = [td.text.replace(u'\xa0',u'') for td in tr.findAll('td')]
        col_by_row2.append(row)
        for th in soup.thead.tr.findAll('th'):
            if len(column_head2)<len(col_by_row2[0]):
                column_head2.append(th.text.replace('▲','').replace('▼',''))

# %%
import pandas as pd


test1_NL = pd.DataFrame(col_by_row2, columns=column_head1)
test1_NL.set_index("RK")
test1_NL.to_csv('Question_2A_1.csv')

# %%
test1_NL
# Out:
#     RK                   Team      League    G    AB    R     H   2B  3B  \
# 0    1   San Francisco Giants   sf     NL  162  5565  696  1486  288  39
# 1    2       Colorado Rockies  col     NL  162  5572  737  1479  274  49
# 2    3   Arizona Diamondbacks  ari     NL  162  5649  720  1494  289  48
# 3    4          Miami Marlins  mia     NL  162  5463  613  1420  236  40
# 4    5     Pittsburgh Pirates  pit     NL  162  5631  697  1462  292  27
# 5    6    St. Louis Cardinals  stl     NL  162  5484  647  1386  288  39
# 6    7      Milwaukee Brewers  mil     NL  162  5480  655  1378  274  34
# 7    8         Atlanta Braves  atl     NL  162  5420  573  1361  251  18
# 8    9   Washington Nationals  was     NL  162  5428  703  1363  265  13
# 9   10    Los Angeles Dodgers   la     NL  162  5385  667  1346  263  26
# 10  11  Philadelphia Phillies  phi     NL  162  5529  626  1374  272  37
# 11  12        Cincinnati Reds  cin     NL  162  5571  640  1382  257  27
# ...

# %%
b=test1_NL['HR']
import numpy as np

m1=[]
for i in b:
    m1.append(int(i))
m1
Average_NL = np.mean(m1)
Average_NL
# Out:
# 151.66666666666666

# %%
if (Average_AL>Average_NL):
    print("American league had the greatest average number of homeruns in 2015:{}".format(Average_AL))
else:
        print("National league had the greatest average number of homeruns in 2015:{}".format(Average_NL))
# Out:
# American league had the greatest average number of homeruns in 2015:175.6

# %% [markdown]
# FIRST INNING

# %%
hitting_inning_element = driver.find_element_by_id("st_hitting_hitting_splits")
group_select = hitting_inning_element.find_element_by_tag_name("optgroup")

# %%
inning_select = group_select.find_element_by_xpath('//*[@id="st_hitting_hitting_splits"]/optgroup[9]/option[1]')

# %%
inning_select.click()

# %%
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = BeautifulSoup(data_html, 'html5lib')

# %%
column_head3=[]
col_by_row3=[]
for tr in soup.tbody.findAll('tr'):
        row = [td.text.replace(u'\xa0',u'') for td in tr.findAll('td')]
        col_by_row3.append(row)
        for th in soup.thead.tr.findAll('th'):
            if len(column_head3)<len(col_by_row3[0]):
                column_head3.append(th.text.replace('▲','').replace('▼',''))

# %%
import pandas as pd


test1_NL_battingfirst = pd.DataFrame(col_by_row3, columns=column_head3)
test1_NL_battingfirst.set_index("RK")
test1_NL_battingfirst.to_csv('Question_2B.csv')

# %%
test1_NL_battingfirst
# Out:
#     RK                   Team      League    G   AB    R    H  2B 3B ...  SAC  \
# 0    1          Miami Marlins  mia     NL  165  689   98  219  25  9 ...    6
# 1    2   Arizona Diamondbacks  ari     NL  169  705  105  210  40  7 ...    3
# 2    3  Philadelphia Phillies  phi     NL  171  703   91  205  36  7 ...    3
# 3    4   San Francisco Giants   sf     NL  205  679   95  197  34  3 ...    1
# 4    5       Colorado Rockies  col     NL  171  671  101  194  33  9 ...    5
# 5    6      Milwaukee Brewers  mil     NL  183  691   97  194  34  8 ...    4
# 6    7   Washington Nationals  was     NL  175  683   90  187  40  2 ...    1
# 7    8    St. Louis Cardinals  stl     NL  187  669  108  179  49  4 ...    0
# 8    9     Pittsburgh Pirates  pit     NL  175  699   96  186  44  6 ...    1
# 9   10           Chicago Cubs  chc     NL  183  661  109  170  36  8 ...    1
# 10  11          New York Mets  nym     NL  176  656  102  168  35  3 ...    0
# ...

# %%
c=test1_NL_battingfirst['HR']
import numpy as np

m2=[]
for i in c:
    m2.append(int(i))
m2
Average_NL_battingfirst = np.mean(m2)
Average_NL_battingfirst
# Out:
# 15.066666666666666

# %% [markdown]
# AL FIRST INNING

# %%
hitting_AL = driver.find_element_by_xpath('//*[@id="st_hitting-0"]/fieldset[2]/label[2]')
hitting_AL.click()
data_div = driver.find_element_by_id('datagrid')
data_html = data_div.get_attribute('innerHTML')
soup = BeautifulSoup(data_html, 'html5lib')

# %%
column_head4=[]
col_by_row4=[]
for tr in soup.tbody.findAll('tr'):
        row = [td.text.replace(u'\xa0',u'') for td in tr.findAll('td')]
        col_by_row4.append(row)
        for th in soup.thead.tr.findAll('th'):
            if len(column_head4)<len(col_by_row4[0]):
                column_head4.append(th.text.replace('▲','').replace('▼',''))

# %%
import pandas as pd
test1_AL_battingfirst = pd.DataFrame(col_by_row4, columns=column_head1)
test1_AL_battingfirst.set_index("RK")
test1_AL_battingfirst.to_csv('Question_2B_1.csv')

# %%
test1_AL_battingfirst
# Out:
#     RK                Team      League    G   AB    R    H  2B  3B ...  SAC  \
# 0    1      Houston Astros  hou     AL  172  684   97  214  35   4 ...    2
# 1    2      Boston Red Sox  bos     AL  166  699  112  208  44   8 ...    2
# 2    3   Cleveland Indians  cle     AL  168  659  100  191  48   7 ...    6
# 3    4   Chicago White Sox  cws     AL  173  661   99  187  31   9 ...    5
# 4    5   Baltimore Orioles  bal     AL  184  662   99  187  30   3 ...    2
# 5    6   Toronto Blue Jays  tor     AL  181  696  100  187  36   1 ...    6
# 6    7      Detroit Tigers  det     AL  184  698  100  186  31  17 ...    2
# 7    8    New York Yankees  nyy     AL  174  689  111  182  33   4 ...    2
# 8    9      Tampa Bay Rays   tb     AL  219  658   85  170  37   6 ...    3
# 9   10   Oakland Athletics  oak     AL  173  704   94  177  26  11 ...    2
# 10  11  Kansas City Royals   kc     AL  173  684   94  171  23   5 ...   11
# ...

# %%
d=test1_AL_battingfirst['HR']
import numpy as np

m3=[]
for i in d:
    m3.append(int(i))
m3
Average_AL_battingfirst = np.mean(m3)
Average_AL_battingfirst
# Out:
# 15.133333333333333

# %%
if (Average_AL_battingfirst>Average_NL_battingfirst):
    print("American league had the greatest average number of homeruns in 2015 while batting first:{}".format(Average_AL_battingfirst))
else:
        print("National league had the greatest average number of homeruns in 2015 while batting first:{}".format(Average_NL_battingfirst))
# Out:
# American league had the greatest average number of homeruns in 2015 while batting first:15.133333333333333
